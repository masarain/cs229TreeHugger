# %%
import pandas as pd
from sklearn import svm
filepath = "train_v2.csv"

# %%
df = pd.read_csv(filepath)
df = df.drop([i for i in range(500, df.shape[0])])
labels = set()

# %%
for index, row in df.iterrows():
    currLabels = row[1]
    for label in currLabels.split():
        labels.add(label)
# Out:
# image_name         train_0
# tags          haze primary
# Name: 0, dtype: object
# image_name                            train_1
# tags          agriculture clear primary water
# Name: 1, dtype: object
# image_name          train_2
# tags          clear primary
# Name: 2, dtype: object
# image_name          train_3
# tags          clear primary
# Name: 3, dtype: object
# image_name                                      train_4
# tags          agriculture clear habitation primary road
# Name: 4, dtype: object
# image_name               train_5
# tags          haze primary water
# Name: 5, dtype: object
# image_name                                        train_6
# tags          agriculture clear cultivation primary water
# Name: 6, dtype: object
# image_name         train_7
# tags          haze primary
# Name: 7, dtype: object
# image_name                                  train_8
# tags          agriculture clear cultivation primary
# Name: 8, dtype: object
# image_name                                       train_9
# tags          agriculture clear cultivation primary road
# Name: 9, dtype: object
# image_name                                      train_10
# tags          agriculture clear primary slash_burn water
# Name: 10, dtype: object
# image_name               train_11
# tags          clear primary water
# Name: 11, dtype: object
# image_name    train_12
# tags            cloudy
# Name: 12, dtype: object
# image_name         train_13
# tags          clear primary
# Name: 13, dtype: object
# image_name    train_14
# tags            cloudy
# Name: 14, dtype: object
# image_name         train_15
# tags          clear primary
# Name: 15, dtype: object
# image_name         train_16
# tags          clear primary
# Name: 16, dtype: object
# image_name                 train_17
# tags          partly_cloudy primary
# Name: 17, dtype: object
# image_name         train_18
# tags          clear primary
# Name: 18, dtype: object
# image_name                          train_19
# tags          agriculture clear primary road
# Name: 19, dtype: object
# image_name                           train_20
# tags          agriculture clear primary water
# Name: 20, dtype: object
# image_name                    train_21
# tags          clear primary road water
# Name: 21, dtype: object
# image_name                 train_22
# tags          partly_cloudy primary
# Name: 22, dtype: object
# image_name                          train_23
# tags          agriculture clear primary road
# Name: 23, dtype: object
# image_name                                   train_24
# tags          conventional_mine partly_cloudy primary
# Name: 24, dtype: object
# image_name         train_25
# tags          clear primary
# Name: 25, dtype: object
# image_name    train_26
# tags            cloudy
# Name: 26, dtype: object
# image_name                                   train_27
# tags          agriculture partly_cloudy primary water
# Name: 27, dtype: object
# image_name         train_28
# tags          clear primary
# Name: 28, dtype: object
# image_name                 train_29
# tags          partly_cloudy primary
# Name: 29, dtype: object
# image_name               train_30
# tags          clear primary water
# Name: 30, dtype: object
# image_name                     train_31
# tags          clear cultivation primary
# Name: 31, dtype: object
# image_name                          train_32
# tags          agriculture clear primary road
# Name: 32, dtype: object
# image_name                                         train_33
# tags          agriculture cultivation partly_cloudy primary
# Name: 33, dtype: object
# image_name         train_34
# tags          clear primary
# Name: 34, dtype: object
# image_name         train_35
# tags          clear primary
# Name: 35, dtype: object
# image_name                          train_36
# tags          agriculture clear primary road
# Name: 36, dtype: object
# image_name                 train_37
# tags          partly_cloudy primary
# Name: 37, dtype: object
# image_name         train_38
# tags          clear primary
# Name: 38, dtype: object
# image_name         train_39
# tags          clear primary
# Name: 39, dtype: object
# image_name                                 train_40
# tags          agriculture clear cultivation primary
# Name: 40, dtype: object
# image_name                     train_41
# tags          agriculture clear primary
# Name: 41, dtype: object
# image_name         train_42
# tags          clear primary
# Name: 42, dtype: object
# image_name            train_43
# tags          bare_ground haze
# Name: 43, dtype: object
# image_name         train_44
# tags          clear primary
# Name: 44, dtype: object
# image_name         train_45
# tags          clear primary
# Name: 45, dtype: object
# image_name                                train_46
# tags          bare_ground clear habitation primary
# Name: 46, dtype: object
# image_name               train_47
# tags          clear primary water
# Name: 47, dtype: object
# image_name               train_48
# tags          clear primary water
# Name: 48, dtype: object
# image_name         train_49
# tags          clear primary
# Name: 49, dtype: object
# image_name    train_50
# tags            cloudy
# Name: 50, dtype: object
# image_name         train_51
# tags          clear primary
# Name: 51, dtype: object
# image_name                                           train_52
# tags          agriculture clear habitation primary road water
# Name: 52, dtype: object
# image_name         train_53
# tags          clear primary
# Name: 53, dtype: object
# image_name         train_54
# tags          clear primary
# Name: 54, dtype: object
# image_name                            train_55
# tags          partly_cloudy primary road water
# Name: 55, dtype: object
# image_name               train_56
# tags          clear primary water
# Name: 56, dtype: object
# image_name                                          train_57
# tags          artisinal_mine bare_ground clear primary water
# Name: 57, dtype: object
# image_name                          train_58
# tags          agriculture clear primary road
# Name: 58, dtype: object
# image_name                                     train_59
# tags          agriculture clear habitation primary road
# Name: 59, dtype: object
# image_name        train_60
# tags          haze primary
# Name: 60, dtype: object
# image_name         train_61
# tags          clear primary
# Name: 61, dtype: object
# image_name               train_62
# tags          clear primary water
# Name: 62, dtype: object
# image_name                          train_63
# tags          agriculture clear primary road
# Name: 63, dtype: object
# image_name                     train_64
# tags          agriculture clear primary
# Name: 64, dtype: object
# image_name         train_65
# tags          clear primary
# Name: 65, dtype: object
# image_name                          train_66
# tags          agriculture clear primary road
# Name: 66, dtype: object
# image_name                         train_67
# tags          clear habitation primary road
# Name: 67, dtype: object
# image_name    train_68
# tags            cloudy
# Name: 68, dtype: object
# image_name         train_69
# tags          clear primary
# Name: 69, dtype: object
# image_name                  train_70
# tags          blooming clear primary
# Name: 70, dtype: object
# image_name               train_71
# tags          clear primary water
# Name: 71, dtype: object
# image_name    train_72
# tags            cloudy
# Name: 72, dtype: object
# image_name         train_73
# tags          clear primary
# Name: 73, dtype: object
# image_name                                  train_74
# tags          agriculture partly_cloudy primary road
# Name: 74, dtype: object
# image_name                                train_75
# tags          agriculture clear primary road water
# Name: 75, dtype: object
# image_name                 train_76
# tags          partly_cloudy primary
# Name: 76, dtype: object
# image_name    train_77
# tags            cloudy
# Name: 77, dtype: object
# image_name         train_78
# tags          clear primary
# Name: 78, dtype: object
# image_name                     train_79
# tags          clear cultivation primary
# Name: 79, dtype: object
# image_name                                  train_80
# tags          agriculture partly_cloudy primary road
# Name: 80, dtype: object
# image_name         train_81
# tags          clear primary
# Name: 81, dtype: object
# image_name                                             train_82
# tags          blooming clear cultivation habitation primary ...
# Name: 82, dtype: object
# image_name         train_83
# tags          clear primary
# Name: 83, dtype: object
# image_name                                     train_84
# tags          agriculture clear habitation primary road
# Name: 84, dtype: object
# image_name               train_85
# tags          clear primary water
# Name: 85, dtype: object
# image_name         train_86
# tags          clear primary
# Name: 86, dtype: object
# image_name    train_87
# tags            cloudy
# Name: 87, dtype: object
# image_name                 train_88
# tags          partly_cloudy primary
# Name: 88, dtype: object
# image_name         train_89
# tags          clear primary
# Name: 89, dtype: object
# image_name                                  train_90
# tags          agriculture partly_cloudy primary road
# Name: 90, dtype: object
# image_name                 train_91
# tags          partly_cloudy primary
# Name: 91, dtype: object
# image_name                                     train_92
# tags          agriculture clear habitation primary road
# Name: 92, dtype: object
# image_name         train_93
# tags          clear primary
# Name: 93, dtype: object
# image_name                                     train_94
# tags          agriculture clear habitation primary road
# Name: 94, dtype: object
# image_name         train_95
# tags          clear primary
# Name: 95, dtype: object
# image_name         train_96
# tags          clear primary
# Name: 96, dtype: object
# image_name    train_97
# tags            cloudy
# Name: 97, dtype: object
# image_name         train_98
# tags          clear primary
# Name: 98, dtype: object
# image_name                 train_99
# tags          partly_cloudy primary
# Name: 99, dtype: object
# image_name                  train_100
# tags          bare_ground clear water
# Name: 100, dtype: object
# image_name    train_101
# tags             cloudy
# Name: 101, dtype: object
# image_name        train_102
# tags          clear primary
# Name: 102, dtype: object
# image_name                                          train_103
# tags          agriculture clear habitation primary road water
# Name: 103, dtype: object
# image_name       train_104
# tags          haze primary
# Name: 104, dtype: object
# image_name        train_105
# tags          clear primary
# Name: 105, dtype: object
# image_name        train_106
# tags          clear primary
# Name: 106, dtype: object
# image_name                train_107
# tags          partly_cloudy primary
# Name: 107, dtype: object
# image_name    train_108
# tags             cloudy
# Name: 108, dtype: object
# image_name        train_109
# tags          clear primary
# Name: 109, dtype: object
# image_name        train_110
# tags          clear primary
# Name: 110, dtype: object
# image_name    train_111
# tags             cloudy
# Name: 111, dtype: object
# image_name                         train_112
# tags          agriculture clear primary road
# Name: 112, dtype: object
# image_name                    train_113
# tags          agriculture clear primary
# Name: 113, dtype: object
# image_name              train_114
# tags          clear primary water
# Name: 114, dtype: object
# image_name              train_115
# tags          clear primary water
# Name: 115, dtype: object
# image_name                         train_116
# tags          agriculture clear primary road
# Name: 116, dtype: object
# image_name        train_117
# tags          clear primary
# Name: 117, dtype: object
# image_name    train_118
# tags             cloudy
# Name: 118, dtype: object
# image_name                               train_119
# tags          agriculture clear primary road water
# Name: 119, dtype: object
# image_name        train_120
# tags          clear primary
# Name: 120, dtype: object
# image_name                      train_121
# tags          partly_cloudy primary water
# Name: 121, dtype: object
# image_name                         train_122
# tags          agriculture clear primary road
# Name: 122, dtype: object
# image_name                                            train_123
# tags          agriculture bare_ground clear habitation prima...
# Name: 123, dtype: object
# image_name                    train_124
# tags          bare_ground clear primary
# Name: 124, dtype: object
# image_name                    train_125
# tags          agriculture clear primary
# Name: 125, dtype: object
# image_name                         train_126
# tags          agriculture clear primary road
# Name: 126, dtype: object
# image_name        train_127
# tags          clear primary
# Name: 127, dtype: object
# image_name        train_128
# tags          clear primary
# Name: 128, dtype: object
# image_name                    train_129
# tags          agriculture clear primary
# Name: 129, dtype: object
# image_name                train_130
# tags          partly_cloudy primary
# Name: 130, dtype: object
# image_name                               train_131
# tags          agriculture clear primary road water
# Name: 131, dtype: object
# image_name       train_132
# tags          haze primary
# Name: 132, dtype: object
# image_name       train_133
# tags          haze primary
# Name: 133, dtype: object
# image_name        train_134
# tags          clear primary
# Name: 134, dtype: object
# image_name              train_135
# tags          clear primary water
# Name: 135, dtype: object
# image_name       train_136
# tags          haze primary
# Name: 136, dtype: object
# image_name        train_137
# tags          clear primary
# Name: 137, dtype: object
# image_name    train_138
# tags             cloudy
# Name: 138, dtype: object
# image_name        train_139
# tags          clear primary
# Name: 139, dtype: object
# image_name        train_140
# tags          clear primary
# Name: 140, dtype: object
# image_name                      train_141
# tags          partly_cloudy primary water
# Name: 141, dtype: object
# image_name                                    train_142
# tags          agriculture clear habitation primary road
# Name: 142, dtype: object
# image_name                      train_143
# tags          partly_cloudy primary water
# Name: 143, dtype: object
# image_name                                            train_144
# tags          agriculture partly_cloudy primary selective_lo...
# Name: 144, dtype: object
# image_name                train_145
# tags          partly_cloudy primary
# Name: 145, dtype: object
# image_name                    train_146
# tags          clear cultivation primary
# Name: 146, dtype: object
# image_name        train_147
# tags          clear primary
# Name: 147, dtype: object
# image_name                                      train_148
# tags          agriculture clear cultivation primary water
# Name: 148, dtype: object
# image_name        train_149
# tags          clear primary
# Name: 149, dtype: object
# image_name                            train_150
# tags          agriculture partly_cloudy primary
# Name: 150, dtype: object
# image_name                                            train_151
# tags          agriculture clear cultivation primary selectiv...
# Name: 151, dtype: object
# image_name       train_152
# tags          haze primary
# Name: 152, dtype: object
# image_name        train_153
# tags          clear primary
# Name: 153, dtype: object
# image_name        train_154
# tags          clear primary
# Name: 154, dtype: object
# image_name        train_155
# tags          clear primary
# Name: 155, dtype: object
# image_name              train_156
# tags          clear primary water
# Name: 156, dtype: object
# image_name                            train_157
# tags          agriculture partly_cloudy primary
# Name: 157, dtype: object
# image_name                          train_158
# tags          agriculture clear primary water
# Name: 158, dtype: object
# image_name                         train_159
# tags          agriculture clear primary road
# Name: 159, dtype: object
# image_name                train_160
# tags          partly_cloudy primary
# Name: 160, dtype: object
# image_name                train_161
# tags          partly_cloudy primary
# Name: 161, dtype: object
# image_name                            train_162
# tags          agriculture partly_cloudy primary
# Name: 162, dtype: object
# image_name        train_163
# tags          clear primary
# Name: 163, dtype: object
# image_name        train_164
# tags          clear primary
# Name: 164, dtype: object
# image_name              train_165
# tags          clear primary water
# Name: 165, dtype: object
# image_name                                     train_166
# tags          clear primary road selective_logging water
# Name: 166, dtype: object
# image_name                                            train_167
# tags          agriculture habitation partly_cloudy primary road
# Name: 167, dtype: object
# image_name    train_168
# tags             cloudy
# Name: 168, dtype: object
# image_name                         train_169
# tags          agriculture clear primary road
# Name: 169, dtype: object
# image_name              train_170
# tags          clear primary water
# Name: 170, dtype: object
# image_name                         train_171
# tags          agriculture clear primary road
# Name: 171, dtype: object
# image_name                         train_172
# tags          agriculture clear primary road
# Name: 172, dtype: object
# image_name                    train_173
# tags          clear cultivation primary
# Name: 173, dtype: object
# image_name    train_174
# tags             cloudy
# Name: 174, dtype: object
# image_name        train_175
# tags          clear primary
# Name: 175, dtype: object
# image_name        train_176
# tags          clear primary
# Name: 176, dtype: object
# image_name                               train_177
# tags          agriculture clear primary road water
# Name: 177, dtype: object
# image_name        train_178
# tags          clear primary
# Name: 178, dtype: object
# image_name    train_179
# tags             cloudy
# Name: 179, dtype: object
# image_name       train_180
# tags          haze primary
# Name: 180, dtype: object
# image_name        train_181
# tags          clear primary
# Name: 181, dtype: object
# image_name                train_182
# tags          partly_cloudy primary
# Name: 182, dtype: object
# image_name        train_183
# tags          clear primary
# Name: 183, dtype: object
# image_name                train_184
# tags          partly_cloudy primary
# Name: 184, dtype: object
# image_name                                            train_185
# tags          agriculture artisinal_mine clear cultivation h...
# Name: 185, dtype: object
# image_name                   train_186
# tags          clear primary road water
# Name: 186, dtype: object
# image_name                            train_187
# tags          artisinal_mine clear primary road
# Name: 187, dtype: object
# image_name              train_188
# tags          clear primary water
# Name: 188, dtype: object
# image_name                   train_189
# tags          clear primary road water
# Name: 189, dtype: object
# image_name        train_190
# tags          clear primary
# Name: 190, dtype: object
# image_name                train_191
# tags          partly_cloudy primary
# Name: 191, dtype: object
# image_name                  train_192
# tags          blow_down clear primary
# Name: 192, dtype: object
# image_name                train_193
# tags          partly_cloudy primary
# Name: 193, dtype: object
# image_name                train_194
# tags          partly_cloudy primary
# Name: 194, dtype: object
# image_name                         train_195
# tags          agriculture clear primary road
# Name: 195, dtype: object
# image_name       train_196
# tags          haze primary
# Name: 196, dtype: object
# image_name                         train_197
# tags          agriculture clear primary road
# Name: 197, dtype: object
# image_name        train_198
# tags          clear primary
# Name: 198, dtype: object
# image_name                                train_199
# tags          agriculture clear cultivation primary
# Name: 199, dtype: object
# image_name        train_200
# tags          clear primary
# Name: 200, dtype: object
# image_name        train_201
# tags          clear primary
# Name: 201, dtype: object
# image_name                train_202
# tags          clear habitation road
# Name: 202, dtype: object
# image_name    train_203
# tags             cloudy
# Name: 203, dtype: object
# image_name        train_204
# tags          clear primary
# Name: 204, dtype: object
# image_name                                train_205
# tags          agriculture clear cultivation primary
# Name: 205, dtype: object
# image_name                train_206
# tags          partly_cloudy primary
# Name: 206, dtype: object
# image_name                         train_207
# tags          bare_ground clear primary road
# Name: 207, dtype: object
# image_name        train_208
# tags          clear primary
# Name: 208, dtype: object
# image_name                         train_209
# tags          agriculture clear primary road
# Name: 209, dtype: object
# image_name                train_210
# tags          partly_cloudy primary
# Name: 210, dtype: object
# image_name                        train_211
# tags          clear habitation primary road
# Name: 211, dtype: object
# image_name                train_212
# tags          partly_cloudy primary
# Name: 212, dtype: object
# image_name                               train_213
# tags          agriculture clear primary road water
# Name: 213, dtype: object
# image_name        train_214
# tags          clear primary
# Name: 214, dtype: object
# image_name             train_215
# tags          haze primary water
# Name: 215, dtype: object
# image_name                         train_216
# tags          agriculture clear primary road
# Name: 216, dtype: object
# image_name                    train_217
# tags          bare_ground clear primary
# Name: 217, dtype: object
# image_name                                            train_218
# tags          agriculture clear cultivation habitation prima...
# Name: 218, dtype: object
# image_name        train_219
# tags          clear primary
# Name: 219, dtype: object
# image_name                train_220
# tags          partly_cloudy primary
# Name: 220, dtype: object
# image_name        train_221
# tags          clear primary
# Name: 221, dtype: object
# image_name                                            train_222
# tags          agriculture clear cultivation habitation prima...
# Name: 222, dtype: object
# image_name        train_223
# tags          clear primary
# Name: 223, dtype: object
# image_name                    train_224
# tags          agriculture clear primary
# Name: 224, dtype: object
# image_name                                            train_225
# tags          agriculture clear cultivation habitation prima...
# Name: 225, dtype: object
# image_name    train_226
# tags             cloudy
# Name: 226, dtype: object
# image_name                                train_227
# tags          agriculture clear cultivation primary
# Name: 227, dtype: object
# image_name                              train_228
# tags          agriculture haze primary road water
# Name: 228, dtype: object
# image_name                                train_229
# tags          agriculture clear cultivation primary
# Name: 229, dtype: object
# image_name                                            train_230
# tags          agriculture bare_ground habitation partly_clou...
# Name: 230, dtype: object
# image_name                train_231
# tags          partly_cloudy primary
# Name: 231, dtype: object
# image_name        train_232
# tags          clear primary
# Name: 232, dtype: object
# image_name              train_233
# tags          clear primary water
# Name: 233, dtype: object
# image_name    train_234
# tags             cloudy
# Name: 234, dtype: object
# image_name        train_235
# tags          clear primary
# Name: 235, dtype: object
# image_name        train_236
# tags          clear primary
# Name: 236, dtype: object
# image_name                                  train_237
# tags          artisinal_mine clear primary road water
# Name: 237, dtype: object
# image_name        train_238
# tags          clear primary
# Name: 238, dtype: object
# image_name                          train_239
# tags          bare_ground clear primary water
# Name: 239, dtype: object
# image_name                         train_240
# tags          agriculture clear primary road
# Name: 240, dtype: object
# image_name                        train_241
# tags          agriculture haze primary road
# Name: 241, dtype: object
# image_name        train_242
# tags          clear primary
# Name: 242, dtype: object
# image_name        train_243
# tags          clear primary
# Name: 243, dtype: object
# image_name        train_244
# tags          clear primary
# Name: 244, dtype: object
# image_name                 train_245
# tags          clear primary blooming
# Name: 245, dtype: object
# image_name        train_246
# tags          clear primary
# Name: 246, dtype: object
# image_name                                            train_247
# tags          agriculture clear cultivation habitation prima...
# Name: 247, dtype: object
# image_name       train_248
# tags          haze primary
# Name: 248, dtype: object
# image_name                train_249
# tags          partly_cloudy primary
# Name: 249, dtype: object
# image_name        train_250
# tags          clear primary
# Name: 250, dtype: object
# image_name        train_251
# tags          clear primary
# Name: 251, dtype: object
# image_name                   train_252
# tags          clear habitation primary
# Name: 252, dtype: object
# image_name                                    train_253
# tags          agriculture clear habitation primary road
# Name: 253, dtype: object
# image_name        train_254
# tags          clear primary
# Name: 254, dtype: object
# image_name                                    train_255
# tags          agriculture clear habitation primary road
# Name: 255, dtype: object
# image_name                                train_256
# tags          agriculture clear cultivation primary
# Name: 256, dtype: object
# image_name    train_257
# tags             cloudy
# Name: 257, dtype: object
# image_name                        train_258
# tags          clear habitation primary road
# Name: 258, dtype: object
# image_name                train_259
# tags          partly_cloudy primary
# Name: 259, dtype: object
# image_name                   train_260
# tags          clear primary road water
# Name: 260, dtype: object
# image_name                    train_261
# tags          agriculture clear primary
# Name: 261, dtype: object
# image_name                    train_262
# tags          clear cultivation primary
# Name: 262, dtype: object
# image_name                    train_263
# tags          agriculture clear primary
# Name: 263, dtype: object
# image_name        train_264
# tags          clear primary
# Name: 264, dtype: object
# image_name                train_265
# tags          partly_cloudy primary
# Name: 265, dtype: object
# image_name                               train_266
# tags          clear cultivation habitation primary
# Name: 266, dtype: object
# image_name                train_267
# tags          partly_cloudy primary
# Name: 267, dtype: object
# image_name                                    train_268
# tags          agriculture clear habitation primary road
# Name: 268, dtype: object
# image_name        train_269
# tags          clear primary
# Name: 269, dtype: object
# image_name                         train_270
# tags          agriculture clear primary road
# Name: 270, dtype: object
# image_name        train_271
# tags          clear primary
# Name: 271, dtype: object
# image_name                         train_272
# tags          agriculture clear primary road
# Name: 272, dtype: object
# image_name      train_273
# tags          clear water
# Name: 273, dtype: object
# image_name                                  train_274
# tags          artisinal_mine clear primary road water
# Name: 274, dtype: object
# image_name        train_275
# tags          clear primary
# Name: 275, dtype: object
# image_name                train_276
# tags          partly_cloudy primary
# Name: 276, dtype: object
# image_name        train_277
# tags          clear primary
# Name: 277, dtype: object
# image_name        train_278
# tags          clear primary
# Name: 278, dtype: object
# image_name                    train_279
# tags          clear cultivation primary
# Name: 279, dtype: object
# image_name                train_280
# tags          partly_cloudy primary
# Name: 280, dtype: object
# image_name                          train_281
# tags          clear primary selective_logging
# Name: 281, dtype: object
# image_name                train_282
# tags          partly_cloudy primary
# Name: 282, dtype: object
# image_name                      train_283
# tags          partly_cloudy primary water
# Name: 283, dtype: object
# image_name    train_284
# tags             cloudy
# Name: 284, dtype: object
# image_name    train_285
# tags             cloudy
# Name: 285, dtype: object
# image_name                                         train_286
# tags          agriculture artisinal_mine clear primary water
# Name: 286, dtype: object
# image_name                train_287
# tags          partly_cloudy primary
# Name: 287, dtype: object
# image_name              train_288
# tags          clear primary water
# Name: 288, dtype: object
# image_name        train_289
# tags          clear primary
# Name: 289, dtype: object
# image_name      train_290
# tags          clear water
# Name: 290, dtype: object
# image_name                         train_291
# tags          agriculture clear primary road
# Name: 291, dtype: object
# image_name                            train_292
# tags          agriculture partly_cloudy primary
# Name: 292, dtype: object
# image_name              train_293
# tags          clear primary water
# Name: 293, dtype: object
# image_name             train_294
# tags          clear primary road
# Name: 294, dtype: object
# image_name              train_295
# tags          clear primary water
# Name: 295, dtype: object
# image_name        train_296
# tags          clear primary
# Name: 296, dtype: object
# image_name                                train_297
# tags          agriculture clear cultivation primary
# Name: 297, dtype: object
# image_name                                            train_298
# tags          agriculture bare_ground clear cultivation habi...
# Name: 298, dtype: object
# image_name        train_299
# tags          clear primary
# Name: 299, dtype: object
# image_name        train_300
# tags          clear primary
# Name: 300, dtype: object
# image_name                               train_301
# tags          agriculture clear primary road water
# Name: 301, dtype: object
# image_name    train_302
# tags             cloudy
# Name: 302, dtype: object
# image_name                    train_303
# tags          agriculture clear primary
# Name: 303, dtype: object
# image_name                    train_304
# tags          agriculture clear primary
# Name: 304, dtype: object
# image_name                train_305
# tags          partly_cloudy primary
# Name: 305, dtype: object
# image_name                train_306
# tags          partly_cloudy primary
# Name: 306, dtype: object
# image_name        train_307
# tags          clear primary
# Name: 307, dtype: object
# image_name                                            train_308
# tags          agriculture cultivation partly_cloudy primary ...
# Name: 308, dtype: object
# image_name                          train_309
# tags          agriculture clear primary water
# Name: 309, dtype: object
# image_name        train_310
# tags          clear primary
# Name: 310, dtype: object
# image_name                                    train_311
# tags          agriculture clear habitation primary road
# Name: 311, dtype: object
# image_name                train_312
# tags          partly_cloudy primary
# Name: 312, dtype: object
# image_name              train_313
# tags          clear primary water
# Name: 313, dtype: object
# image_name                         train_314
# tags          agriculture clear primary road
# Name: 314, dtype: object
# image_name                        train_315
# tags          agriculture haze primary road
# Name: 315, dtype: object
# image_name                    train_316
# tags          agriculture clear primary
# Name: 316, dtype: object
# image_name        train_317
# tags          clear primary
# Name: 317, dtype: object
# image_name        train_318
# tags          clear primary
# Name: 318, dtype: object
# image_name                 train_319
# tags          bare_ground clear road
# Name: 319, dtype: object
# image_name                train_320
# tags          partly_cloudy primary
# Name: 320, dtype: object
# image_name              train_321
# tags          clear primary water
# Name: 321, dtype: object
# image_name                   train_322
# tags          clear primary road water
# Name: 322, dtype: object
# image_name                train_323
# tags          partly_cloudy primary
# Name: 323, dtype: object
# image_name                          train_324
# tags          agriculture clear primary water
# Name: 324, dtype: object
# image_name       train_325
# tags          haze primary
# Name: 325, dtype: object
# image_name                    train_326
# tags          agriculture clear primary
# Name: 326, dtype: object
# image_name        train_327
# tags          clear primary
# Name: 327, dtype: object
# image_name                                 train_328
# tags          agriculture partly_cloudy primary road
# Name: 328, dtype: object
# image_name                   train_329
# tags          clear primary road water
# Name: 329, dtype: object
# image_name                          train_330
# tags          agriculture clear primary water
# Name: 330, dtype: object
# image_name                train_331
# tags          partly_cloudy primary
# Name: 331, dtype: object
# image_name       train_332
# tags          haze primary
# Name: 332, dtype: object
# image_name                         train_333
# tags          agriculture clear primary road
# Name: 333, dtype: object
# image_name                           train_334
# tags          partly_cloudy primary road water
# Name: 334, dtype: object
# image_name        train_335
# tags          clear primary
# Name: 335, dtype: object
# image_name        train_336
# tags          clear primary
# Name: 336, dtype: object
# image_name    train_337
# tags             cloudy
# Name: 337, dtype: object
# image_name                    train_338
# tags          agriculture clear primary
# Name: 338, dtype: object
# image_name        train_339
# tags          clear primary
# Name: 339, dtype: object
# image_name                   train_340
# tags          partly_cloudy road water
# Name: 340, dtype: object
# image_name       train_341
# tags          haze primary
# Name: 341, dtype: object
# image_name                                 train_342
# tags          agriculture partly_cloudy primary road
# Name: 342, dtype: object
# image_name    train_343
# tags             cloudy
# Name: 343, dtype: object
# image_name        train_344
# tags          clear primary
# Name: 344, dtype: object
# image_name                    train_345
# tags          agriculture clear primary
# Name: 345, dtype: object
# image_name        train_346
# tags          clear primary
# Name: 346, dtype: object
# image_name                           train_347
# tags          partly_cloudy primary road water
# Name: 347, dtype: object
# image_name        train_348
# tags          clear primary
# Name: 348, dtype: object
# image_name                    train_349
# tags          agriculture clear primary
# Name: 349, dtype: object
# image_name                         train_350
# tags          agriculture clear primary road
# Name: 350, dtype: object
# image_name                        train_351
# tags          agriculture haze primary road
# Name: 351, dtype: object
# image_name    train_352
# tags             cloudy
# Name: 352, dtype: object
# image_name                                            train_353
# tags          agriculture habitation partly_cloudy primary road
# Name: 353, dtype: object
# image_name        train_354
# tags          clear primary
# Name: 354, dtype: object
# image_name        train_355
# tags          clear primary
# Name: 355, dtype: object
# image_name        train_356
# tags          clear primary
# Name: 356, dtype: object
# image_name        train_357
# tags          clear primary
# Name: 357, dtype: object
# image_name                                train_358
# tags          agriculture clear cultivation primary
# Name: 358, dtype: object
# image_name                            train_359
# tags          agriculture partly_cloudy primary
# Name: 359, dtype: object
# image_name       train_360
# tags          haze primary
# Name: 360, dtype: object
# image_name                                 train_361
# tags          agriculture partly_cloudy primary road
# Name: 361, dtype: object
# image_name              train_362
# tags          clear primary water
# Name: 362, dtype: object
# image_name             train_363
# tags          haze primary water
# Name: 363, dtype: object
# image_name        train_364
# tags          clear primary
# Name: 364, dtype: object
# image_name                train_365
# tags          partly_cloudy primary
# Name: 365, dtype: object
# image_name              train_366
# tags          clear primary water
# Name: 366, dtype: object
# image_name       train_367
# tags          haze primary
# Name: 367, dtype: object
# image_name        train_368
# tags          clear primary
# Name: 368, dtype: object
# image_name                                           train_369
# tags          agriculture clear cultivation habitation primary
# Name: 369, dtype: object
# image_name                                    train_370
# tags          agriculture clear habitation primary road
# Name: 370, dtype: object
# image_name        train_371
# tags          clear primary
# Name: 371, dtype: object
# image_name        train_372
# tags          clear primary
# Name: 372, dtype: object
# image_name        train_373
# tags          clear primary
# Name: 373, dtype: object
# image_name                    train_374
# tags          agriculture clear primary
# Name: 374, dtype: object
# image_name        train_375
# tags          clear primary
# Name: 375, dtype: object
# image_name        train_376
# tags          clear primary
# Name: 376, dtype: object
# image_name                train_377
# tags          partly_cloudy primary
# Name: 377, dtype: object
# image_name        train_378
# tags          clear primary
# Name: 378, dtype: object
# image_name                         train_379
# tags          agriculture clear primary road
# Name: 379, dtype: object
# image_name        train_380
# tags          clear primary
# Name: 380, dtype: object
# image_name                                            train_381
# tags          agriculture clear cultivation habitation prima...
# Name: 381, dtype: object
# image_name        train_382
# tags          clear primary
# Name: 382, dtype: object
# image_name        train_383
# tags          clear primary
# Name: 383, dtype: object
# image_name                train_384
# tags          partly_cloudy primary
# Name: 384, dtype: object
# image_name                                            train_385
# tags          agriculture cultivation habitation partly_clou...
# Name: 385, dtype: object
# image_name                   train_386
# tags          clear primary road water
# Name: 386, dtype: object
# image_name        train_387
# tags          clear primary
# Name: 387, dtype: object
# image_name                   train_388
# tags          agriculture haze primary
# Name: 388, dtype: object
# image_name                         train_389
# tags          agriculture clear primary road
# Name: 389, dtype: object
# image_name                         train_390
# tags          agriculture clear primary road
# Name: 390, dtype: object
# image_name                               train_391
# tags          agriculture clear primary road water
# Name: 391, dtype: object
# image_name                    train_392
# tags          agriculture clear primary
# Name: 392, dtype: object
# image_name                         train_393
# tags          agriculture clear primary road
# Name: 393, dtype: object
# image_name                 train_394
# tags          blooming clear primary
# Name: 394, dtype: object
# image_name                train_395
# tags          partly_cloudy primary
# Name: 395, dtype: object
# image_name    train_396
# tags             cloudy
# Name: 396, dtype: object
# image_name        train_397
# tags          clear primary
# Name: 397, dtype: object
# image_name        train_398
# tags          clear primary
# Name: 398, dtype: object
# image_name        train_399
# tags          clear primary
# Name: 399, dtype: object
# image_name                                  train_400
# tags          agriculture partly_cloudy primary water
# Name: 400, dtype: object
# image_name        train_401
# tags          clear primary
# Name: 401, dtype: object
# image_name                                  train_402
# tags          partly_cloudy primary selective_logging
# Name: 402, dtype: object
# image_name                               train_403
# tags          agriculture clear habitation primary
# Name: 403, dtype: object
# image_name        train_404
# tags          clear primary
# Name: 404, dtype: object
# image_name                         train_405
# tags          agriculture clear primary road
# Name: 405, dtype: object
# image_name                         train_406
# tags          agriculture haze primary water
# Name: 406, dtype: object
# image_name        train_407
# tags          clear primary
# Name: 407, dtype: object
# image_name                 train_408
# tags          blooming clear primary
# Name: 408, dtype: object
# image_name                train_409
# tags          partly_cloudy primary
# Name: 409, dtype: object
# image_name        train_410
# tags          clear primary
# Name: 410, dtype: object
# image_name                               train_411
# tags          agriculture clear primary road water
# Name: 411, dtype: object
# image_name      train_412
# tags          clear water
# Name: 412, dtype: object
# image_name    train_413
# tags             cloudy
# Name: 413, dtype: object
# image_name       train_414
# tags          haze primary
# Name: 414, dtype: object
# image_name        train_415
# tags          clear primary
# Name: 415, dtype: object
# image_name                              train_416
# tags          clear habitation primary road water
# Name: 416, dtype: object
# image_name       train_417
# tags          haze primary
# Name: 417, dtype: object
# image_name                          train_418
# tags          bare_ground clear primary water
# Name: 418, dtype: object
# image_name                                    train_419
# tags          agriculture clear habitation primary road
# Name: 419, dtype: object
# image_name                         train_420
# tags          bare_ground clear primary road
# Name: 420, dtype: object
# image_name                          train_421
# tags          agriculture clear primary water
# Name: 421, dtype: object
# image_name        train_422
# tags          clear primary
# Name: 422, dtype: object
# image_name        train_423
# tags          clear primary
# Name: 423, dtype: object
# image_name        train_424
# tags          clear primary
# Name: 424, dtype: object
# image_name                train_425
# tags          clear habitation road
# Name: 425, dtype: object
# image_name             train_426
# tags          haze primary water
# Name: 426, dtype: object
# image_name        train_427
# tags          clear primary
# Name: 427, dtype: object
# image_name        train_428
# tags          clear primary
# Name: 428, dtype: object
# image_name        train_429
# tags          clear primary
# Name: 429, dtype: object
# image_name                                         train_430
# tags          agriculture blooming clear cultivation primary
# Name: 430, dtype: object
# image_name        train_431
# tags          clear primary
# Name: 431, dtype: object
# image_name       train_432
# tags          haze primary
# Name: 432, dtype: object
# image_name        train_433
# tags          clear primary
# Name: 433, dtype: object
# image_name                            train_434
# tags          agriculture partly_cloudy primary
# Name: 434, dtype: object
# image_name                    train_435
# tags          bare_ground clear primary
# Name: 435, dtype: object
# image_name        train_436
# tags          clear primary
# Name: 436, dtype: object
# image_name    train_437
# tags             cloudy
# Name: 437, dtype: object
# image_name        train_438
# tags          clear primary
# Name: 438, dtype: object
# image_name        train_439
# tags          clear primary
# Name: 439, dtype: object
# image_name                train_440
# tags          partly_cloudy primary
# Name: 440, dtype: object
# image_name                                       train_441
# tags          agriculture partly_cloudy primary road water
# Name: 441, dtype: object
# image_name                          train_442
# tags          agriculture clear primary water
# Name: 442, dtype: object
# image_name        train_443
# tags          clear primary
# Name: 443, dtype: object
# image_name             train_444
# tags          clear primary road
# Name: 444, dtype: object
# image_name                                  train_445
# tags          cultivation partly_cloudy primary water
# Name: 445, dtype: object
# image_name        train_446
# tags          clear primary
# Name: 446, dtype: object
# image_name        train_447
# tags          clear primary
# Name: 447, dtype: object
# image_name                                            train_448
# tags          agriculture artisinal_mine clear primary road ...
# Name: 448, dtype: object
# image_name        train_449
# tags          clear primary
# Name: 449, dtype: object
# image_name              train_450
# tags          clear primary water
# Name: 450, dtype: object
# image_name                    train_451
# tags          bare_ground clear primary
# Name: 451, dtype: object
# image_name              train_452
# tags          partly_cloudy water
# Name: 452, dtype: object
# image_name    train_453
# tags             cloudy
# Name: 453, dtype: object
# image_name             train_454
# tags          haze primary water
# Name: 454, dtype: object
# image_name        train_455
# tags          clear primary
# Name: 455, dtype: object
# image_name                                          train_456
# tags          agriculture clear habitation primary road water
# Name: 456, dtype: object
# image_name        train_457
# tags          clear primary
# Name: 457, dtype: object
# image_name       train_458
# tags          haze primary
# Name: 458, dtype: object
# image_name        train_459
# tags          clear primary
# Name: 459, dtype: object
# image_name       train_460
# tags          haze primary
# Name: 460, dtype: object
# image_name                                       train_461
# tags          agriculture habitation partly_cloudy primary
# Name: 461, dtype: object
# image_name        train_462
# tags          clear primary
# Name: 462, dtype: object
# image_name                   train_463
# tags          clear primary road water
# Name: 463, dtype: object
# image_name                    train_464
# tags          agriculture clear primary
# Name: 464, dtype: object
# image_name                    train_465
# tags          clear cultivation primary
# Name: 465, dtype: object
# image_name        train_466
# tags          clear primary
# Name: 466, dtype: object
# image_name                                train_467
# tags          agriculture clear cultivation primary
# Name: 467, dtype: object
# image_name        train_468
# tags          clear primary
# Name: 468, dtype: object
# image_name        train_469
# tags          clear primary
# Name: 469, dtype: object
# image_name        train_470
# tags          clear primary
# Name: 470, dtype: object
# image_name                                            train_471
# tags          agriculture bare_ground clear cultivation prim...
# Name: 471, dtype: object
# image_name              train_472
# tags          clear primary water
# Name: 472, dtype: object
# image_name        train_473
# tags          clear primary
# Name: 473, dtype: object
# image_name                                  train_474
# tags          agriculture partly_cloudy primary water
# Name: 474, dtype: object
# image_name             train_475
# tags          clear primary road
# Name: 475, dtype: object
# image_name    train_476
# tags             cloudy
# Name: 476, dtype: object
# image_name                                            train_477
# tags          agriculture clear cultivation habitation prima...
# Name: 477, dtype: object
# image_name        train_478
# tags          clear primary
# Name: 478, dtype: object
# image_name        train_479
# tags          clear primary
# Name: 479, dtype: object
# image_name        train_480
# tags          clear primary
# Name: 480, dtype: object
# image_name                train_481
# tags          partly_cloudy primary
# Name: 481, dtype: object
# image_name                train_482
# tags          partly_cloudy primary
# Name: 482, dtype: object
# image_name        train_483
# tags          clear primary
# Name: 483, dtype: object
# image_name        train_484
# tags          clear primary
# Name: 484, dtype: object
# image_name        train_485
# tags          clear primary
# Name: 485, dtype: object
# image_name                    train_486
# tags          bare_ground clear primary
# Name: 486, dtype: object
# image_name        train_487
# tags          clear primary
# Name: 487, dtype: object
# image_name              train_488
# tags          clear primary water
# Name: 488, dtype: object
# image_name              train_489
# tags          clear primary water
# Name: 489, dtype: object
# image_name        train_490
# tags          clear primary
# Name: 490, dtype: object
# image_name                              train_491
# tags          clear habitation primary road water
# Name: 491, dtype: object
# image_name                train_492
# tags          partly_cloudy primary
# Name: 492, dtype: object
# image_name        train_493
# tags          clear primary
# Name: 493, dtype: object
# image_name        train_494
# tags          clear primary
# Name: 494, dtype: object
# image_name              train_495
# tags          clear primary water
# Name: 495, dtype: object
# image_name        train_496
# tags          clear primary
# Name: 496, dtype: object
# image_name        train_497
# tags          clear primary
# Name: 497, dtype: object
# image_name                                          train_498
# tags          agriculture clear habitation primary road water
# Name: 498, dtype: object
# image_name                    train_499
# tags          bare_ground clear primary
# Name: 499, dtype: object

# %%
category = dict()
for i, label in enumerate(sorted(labels)):
    category[label] = i
